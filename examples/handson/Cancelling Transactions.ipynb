# %% [markdown]
# # Cancelling transactions in lusid

# %% [markdown]
# ## Setup LUSID

# %%
import os
import json
from datetime import datetime, timedelta
import pytz

import lusid
import lusid.models as models
from lusid.utilities import ApiClientFactory
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.cocoon.seed_sample_data import seed_data
from lusidtools.cocoon.utilities import create_scope_id

import pandas as pd

pd.set_option('display.max_columns', None)

secrets_path = '/Users/msingh/Projects/lusidws/secrets.json'

api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name='LusidJupyterNotebook'
)

# %%
with open(r'config/build_transactions_mapping.json') as mapping_file:
    build_transactions_json_mapping = json.load(mapping_file)
#    display(build_transactions_json_mapping)
    
with open(r'config/get_holdings_mapping.json') as mapping_file:
    get_holdings_json_mapping = json.load(mapping_file)

# %% [markdown]
# ## 1) Load default transactions into a new scope

# %%
scope = create_scope_id()
portfolio_code = 'EQUITY_UK'
scope
# Out:
# '3a46-ede9-c627-1e'

# %%
transaction_file = r'data/cancels/equity_transactions.csv'
transaction_df = pd.read_csv(transaction_file)
display(transaction_df)
transaction_df['portfolio_code'] = portfolio_code
# Out:
#    portfolio_code                       portfolio_name  \
# 0       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 1       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 2       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 3       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 4       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 5       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 6       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 7       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 8       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 9       EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 10      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 11      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 12      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 13      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 14      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 15      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 16      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 17      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 18      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 19      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
# 20      EQUITY_UK  LUSID's top 10 FTSE stock portfolio
#
#    portfolio_base_currency        ticker    sedol instrument_type  \
# 0                      GBP  GB0002162385   SEDOL1          equity
# 1                      GBP  GB0002162385   SEDOL1          equity
# 2                      GBP  GB0000566504   SEDOL2          equity
# 3                      GBP  GB0000566504   SEDOL2          equity
# 4                      GBP  GB0031348658   SEDOL3          equity
# 5                      GBP  GB0031348658   SEDOL3          equity
# 6                      GBP  GB0007980591   SEDOL4          equity
# 7                      GBP  GB0007980591   SEDOL4          equity
# 8                      GBP  GB0005405286   SEDOL5          equity
# 9                      GBP  GB0005405286   SEDOL5          equity
# 10                     GBP  GB0006043169   SEDOL6          equity
# 11                     GBP  GB0006043169   SEDOL6          equity
# 12                     GBP  GB0008847096   SEDOL7          equity
# 13                     GBP  GB0008847096   SEDOL7          equity
# 14                     GBP  GB00BGDT3G23   SEDOL8          equity
# 15                     GBP  GB00BGDT3G23   SEDOL8          equity
# 16                     GBP  GB00BH4HKS39   SEDOL9          equity
# 17                     GBP  GB00BH4HKS39   SEDOL9          equity
# 18                     GBP  GB00B1XZS820  SEDOL10          equity
# 19                     GBP  GB00B1XZS820  SEDOL10          equity
# 20                     GBP           GBP      GBP            cash
#
#    instrument_id                name    txn_id txn_type txn_trade_date  \
# 0        EQ_1234               Aviva  trd_0001      Buy     02/01/2020
# 1        EQ_1234               Aviva  trd_0002      Buy     02/01/2020
# 2        EQ_1235                 BHP  trd_0003      Buy     02/01/2020
# 3        EQ_1235                 BHP  trd_0004      Buy     02/01/2020
# 4        EQ_1236            Barclays  trd_0005      Buy     02/01/2020
# 5        EQ_1236            Barclays  trd_0006      Buy     02/01/2020
# 6        EQ_1237                  BP  trd_0007      Buy     02/01/2020
# 7        EQ_1237                  BP  trd_0008      Buy     02/01/2020
# 8        EQ_1238                HSBC  trd_0009      Buy     02/01/2020
# 9        EQ_1238                HSBC  trd_0010      Buy     02/01/2020
# 10       EQ_1239           Morrisons  trd_0011      Buy     15/01/2020
# 11       EQ_1239           Morrisons  trd_0012      Buy     15/01/2020
# 12       EQ_1240               Tesco  trd_0022      Buy     15/01/2020
# 13       EQ_1240               Tesco  trd_0014      Buy     16/01/2020
# 14       EQ_1241           Rightmove  trd_0015      Buy     15/01/2020
# 15       EQ_1241           Rightmove  trd_0016      Buy     15/01/2020
# 16       EQ_1242            vodafone  trd_0017      Buy     15/01/2020
# 17       EQ_1242            vodafone  trd_0018      Buy     15/01/2020
# 18       EQ_1243  Anglo American plc  trd_0019      Buy     15/01/2020
# 19       EQ_1243  Anglo American plc  trd_0020      Buy     15/01/2020
# 20           GBP            GBP Cash  trd_0021  FundsIn     02/01/2020
#
#    txn_settle_date  txn_units  txn_price  txn_consideration currency  \
# 0       04/01/2020     120000          5             600000      GBP
# 1       04/01/2020      12000          5              60000      GBP
# 2       04/01/2020      60000         18            1080000      GBP
# 3       04/01/2020      60000         18            1080000      GBP
# 4       04/01/2020     150000          2             300000      GBP
# 5       04/01/2020     150000          2             300000      GBP
# 6       04/01/2020     100000          5             500000      GBP
# 7       04/01/2020     100000          5             500000      GBP
# 8       04/01/2020      20000          6             120000      GBP
# 9       04/01/2020      20000          6             120000      GBP
# 10      17/01/2020     180000          2             360000      GBP
# 11      17/01/2020     180000          2             360000      GBP
# 12      17/01/2020       8000          8              64000      GBP
# 13      18/01/2020       4000          9              36000      GBP
# 14      17/01/2020      80000          6             480000      GBP
# 15      17/01/2020      80000          6             480000      GBP
# 16      17/01/2020     450000          1             450000      GBP
# 17      17/01/2020     450000          1             450000      GBP
# 18      17/01/2020      35000         20             700000      GBP
# 19      17/01/2020      35000         20             700000      GBP
# 20      04/01/2020   12000000          1           12000000      GBP
#
#         strategy cash_transactions
# 0   ftse_tracker               NaN
# 1   ftse_tracker               NaN
# 2   ftse_tracker               NaN
# 3   ftse_tracker               NaN
# 4   ftse_tracker               NaN
# 5   ftse_tracker               NaN
# 6   ftse_tracker               NaN
# 7   ftse_tracker               NaN
# 8   ftse_tracker               NaN
# 9   ftse_tracker               NaN
# 10  ftse_tracker               NaN
# 11  ftse_tracker               NaN
# 12  ftse_tracker               NaN
# 13  ftse_tracker               NaN
# 14  ftse_tracker               NaN
# 15  ftse_tracker               NaN
# 16  ftse_tracker               NaN
# 17  ftse_tracker               NaN
# 18  ftse_tracker               NaN
# 19  ftse_tracker               NaN
# 20  ftse_tracker               GBP

# %%
seed_data_response = seed_data(
    api_factory,
    ['portfolios', 'instruments', 'transactions'],
    scope,
    transaction_file,
    'csv'
)

# %% [markdown]
# ## 2) Lets check our holdings

# %%
txn_port_api = api_factory.build(lusid.api.TransactionPortfoliosApi)

# %%
response = txn_port_api.get_holdings(
    scope=scope,
    code=portfolio_code,
    property_keys=['Instrument/default/Name']
)

holdings_df = lusid_response_to_data_frame(
    response, rename_properties=True, column_name_mapping=get_holdings_json_mapping
)

holdings_df.head(20)
# Out:
#    instrument_scope LusidInstrumentId SubHoldingKeys      InstrumentName  \
# 0           default     LUID_00003D60             {}               Aviva
# 1           default     LUID_00003D61             {}                 BHP
# 2           default     LUID_00003D68             {}            Barclays
# 3           default     LUID_00003D67             {}                  BP
# 4           default     LUID_00003D62             {}                HSBC
# 5           default           CCY_GBP             {}                 GBP
# 6           default     LUID_00003D63             {}           Morrisons
# 7           default     LUID_00003D5Y             {}               Tesco
# 8           default     LUID_00003D65             {}           Rightmove
# 9           default     LUID_00003D5Z             {}            vodafone
# 10          default     LUID_00003D66             {}  Anglo American plc
#
#    SourcePortfolioId SourcePortfolioScope(default-Properties) HoldingType  \
# 0          EQUITY_UK                        3a46-ede9-c627-1e           P
# 1          EQUITY_UK                        3a46-ede9-c627-1e           P
# 2          EQUITY_UK                        3a46-ede9-c627-1e           P
# 3          EQUITY_UK                        3a46-ede9-c627-1e           P
# 4          EQUITY_UK                        3a46-ede9-c627-1e           P
# 5          EQUITY_UK                        3a46-ede9-c627-1e           B
# 6          EQUITY_UK                        3a46-ede9-c627-1e           P
# 7          EQUITY_UK                        3a46-ede9-c627-1e           P
# 8          EQUITY_UK                        3a46-ede9-c627-1e           P
# 9          EQUITY_UK                        3a46-ede9-c627-1e           P
# 10         EQUITY_UK                        3a46-ede9-c627-1e           P
#
#         Units  SettledUnits  Amount-Cost Currency-Cost  \
# 0    132000.0      132000.0     660000.0           GBP
# 1    120000.0      120000.0    2160000.0           GBP
# 2    300000.0      300000.0     600000.0           GBP
# 3    200000.0      200000.0    1000000.0           GBP
# 4     40000.0       40000.0     240000.0           GBP
# 5   3260000.0     3260000.0    3260000.0           GBP
# 6    360000.0      360000.0     720000.0           GBP
# 7     12000.0       12000.0     100000.0           GBP
# 8    160000.0      160000.0     960000.0           GBP
# 9    900000.0      900000.0     900000.0           GBP
# 10    70000.0       70000.0    1400000.0           GBP
#
#     Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 0                  660000.0                       GBP      GBP
# 1                 2160000.0                       GBP      GBP
# 2                  600000.0                       GBP      GBP
# 3                 1000000.0                       GBP      GBP
# 4                  240000.0                       GBP      GBP
# 5                 3260000.0                       GBP      GBP
# 6                  720000.0                       GBP      GBP
# 7                  100000.0                       GBP      GBP
# 8                  960000.0                       GBP      GBP
# 9                  900000.0                       GBP      GBP
# 10                1400000.0                       GBP      GBP

# %% [markdown]
# ## 3) What transactions make up our Aviva and BHP holdings?

# %%
build_transactions_response = txn_port_api.build_transactions(
    scope=scope,
    code=portfolio_code,
    transaction_query_parameters=models.TransactionQueryParameters(
        start_date='2020-01-01', end_date='2021-12-31'
    ),
    property_keys=['Instrument/default/Name']
)

build_transactions_df = lusid_response_to_data_frame(
    build_transactions_response,
    rename_properties=True,
    column_name_mapping=build_transactions_json_mapping,
)

build_transactions_df.head(20)
# Out:
#    TransactionId TransactionType TransactionTypeDesc ClientId  \
# 0       trd_0001             Buy            Purchase  EQ_1234
# 1       trd_0002             Buy            Purchase  EQ_1234
# 2       trd_0003             Buy            Purchase  EQ_1235
# 3       trd_0004             Buy            Purchase  EQ_1235
# 4       trd_0005             Buy            Purchase  EQ_1236
# 5       trd_0006             Buy            Purchase  EQ_1236
# 6       trd_0007             Buy            Purchase  EQ_1237
# 7       trd_0008             Buy            Purchase  EQ_1237
# 8       trd_0009             Buy            Purchase  EQ_1238
# 9       trd_0010             Buy            Purchase  EQ_1238
# 10      trd_0021         FundsIn   Deposit New Funds      NaN
# 11      trd_0011             Buy            Purchase  EQ_1239
# 12      trd_0012             Buy            Purchase  EQ_1239
# 13      trd_0022             Buy            Purchase  EQ_1240
# 14      trd_0015             Buy            Purchase  EQ_1241
# 15      trd_0016             Buy            Purchase  EQ_1241
# 16      trd_0017             Buy            Purchase  EQ_1242
# 17      trd_0018             Buy            Purchase  EQ_1242
# 18      trd_0019             Buy            Purchase  EQ_1243
# 19      trd_0020             Buy            Purchase  EQ_1243
#
#    instrument_scope LusidInstrumentId           TransactionDate  \
# 0           default     LUID_00003D60 2020-01-02 00:00:00+00:00
# 1           default     LUID_00003D60 2020-01-02 00:00:00+00:00
# 2           default     LUID_00003D61 2020-01-02 00:00:00+00:00
# 3           default     LUID_00003D61 2020-01-02 00:00:00+00:00
# 4           default     LUID_00003D68 2020-01-02 00:00:00+00:00
# 5           default     LUID_00003D68 2020-01-02 00:00:00+00:00
# 6           default     LUID_00003D67 2020-01-02 00:00:00+00:00
# 7           default     LUID_00003D67 2020-01-02 00:00:00+00:00
# 8           default     LUID_00003D62 2020-01-02 00:00:00+00:00
# 9           default     LUID_00003D62 2020-01-02 00:00:00+00:00
# 10          default           CCY_GBP 2020-01-02 00:00:00+00:00
# 11          default     LUID_00003D63 2020-01-15 00:00:00+00:00
# 12          default     LUID_00003D63 2020-01-15 00:00:00+00:00
# 13          default     LUID_00003D5Y 2020-01-15 00:00:00+00:00
# 14          default     LUID_00003D65 2020-01-15 00:00:00+00:00
# 15          default     LUID_00003D65 2020-01-15 00:00:00+00:00
# 16          default     LUID_00003D5Z 2020-01-15 00:00:00+00:00
# 17          default     LUID_00003D5Z 2020-01-15 00:00:00+00:00
# 18          default     LUID_00003D66 2020-01-15 00:00:00+00:00
# 19          default     LUID_00003D66 2020-01-15 00:00:00+00:00
#
#               SettlementDate       Units  TransactionAmount  Price PriceType  \
# 0  2020-01-04 00:00:00+00:00    120000.0           600000.0    5.0     Price
# 1  2020-01-04 00:00:00+00:00     12000.0            60000.0    5.0     Price
# 2  2020-01-04 00:00:00+00:00     60000.0          1080000.0   18.0     Price
# 3  2020-01-04 00:00:00+00:00     60000.0          1080000.0   18.0     Price
# 4  2020-01-04 00:00:00+00:00    150000.0           300000.0    2.0     Price
# 5  2020-01-04 00:00:00+00:00    150000.0           300000.0    2.0     Price
# 6  2020-01-04 00:00:00+00:00    100000.0           500000.0    5.0     Price
# 7  2020-01-04 00:00:00+00:00    100000.0           500000.0    5.0     Price
# 8  2020-01-04 00:00:00+00:00     20000.0           120000.0    6.0     Price
# 9  2020-01-04 00:00:00+00:00     20000.0           120000.0    6.0     Price
# 10 2020-01-04 00:00:00+00:00  12000000.0         12000000.0    1.0     Price
# 11 2020-01-17 00:00:00+00:00    180000.0           360000.0    2.0     Price
# 12 2020-01-17 00:00:00+00:00    180000.0           360000.0    2.0     Price
# 13 2020-01-17 00:00:00+00:00      8000.0            64000.0    8.0     Price
# 14 2020-01-17 00:00:00+00:00     80000.0           480000.0    6.0     Price
# 15 2020-01-17 00:00:00+00:00     80000.0           480000.0    6.0     Price
# 16 2020-01-17 00:00:00+00:00    450000.0           450000.0    1.0     Price
# 17 2020-01-17 00:00:00+00:00    450000.0           450000.0    1.0     Price
# 18 2020-01-17 00:00:00+00:00     35000.0           700000.0   20.0     Price
# 19 2020-01-17 00:00:00+00:00     35000.0           700000.0   20.0     Price
#
#     TotalConsideration TotalConsiderationCurrency  ExchangeRate  \
# 0             600000.0                        GBP           1.0
# 1              60000.0                        GBP           1.0
# 2            1080000.0                        GBP           1.0
# 3            1080000.0                        GBP           1.0
# 4             300000.0                        GBP           1.0
# 5             300000.0                        GBP           1.0
# 6             500000.0                        GBP           1.0
# 7             500000.0                        GBP           1.0
# 8             120000.0                        GBP           1.0
# 9             120000.0                        GBP           1.0
# 10          12000000.0                        GBP           1.0
# 11            360000.0                        GBP           1.0
# 12            360000.0                        GBP           1.0
# 13             64000.0                        GBP           1.0
# 14            480000.0                        GBP           1.0
# 15            480000.0                        GBP           1.0
# 16            450000.0                        GBP           1.0
# 17            450000.0                        GBP           1.0
# 18            700000.0                        GBP           1.0
# 19            700000.0                        GBP           1.0
#
#     TransactionToPortfolioRate TransactionCurrency  \
# 0                          0.0                 GBP
# 1                          0.0                 GBP
# 2                          0.0                 GBP
# 3                          0.0                 GBP
# 4                          0.0                 GBP
# 5                          0.0                 GBP
# 6                          0.0                 GBP
# 7                          0.0                 GBP
# 8                          0.0                 GBP
# 9                          0.0                 GBP
# 10                         0.0                 GBP
# 11                         0.0                 GBP
# 12                         0.0                 GBP
# 13                         0.0                 GBP
# 14                         0.0                 GBP
# 15                         0.0                 GBP
# 16                         0.0                 GBP
# 17                         0.0                 GBP
# 18                         0.0                 GBP
# 19                         0.0                 GBP
#
#    strategy(3a46-ede9-c627-1e-Properties)  \
# 0                            ftse_tracker
# 1                            ftse_tracker
# 2                            ftse_tracker
# 3                            ftse_tracker
# 4                            ftse_tracker
# 5                            ftse_tracker
# 6                            ftse_tracker
# 7                            ftse_tracker
# 8                            ftse_tracker
# 9                            ftse_tracker
# 10                           ftse_tracker
# 11                           ftse_tracker
# 12                           ftse_tracker
# 13                           ftse_tracker
# 14                           ftse_tracker
# 15                           ftse_tracker
# 16                           ftse_tracker
# 17                           ftse_tracker
# 18                           ftse_tracker
# 19                           ftse_tracker
#
#    SourcePortfolioId(default-Properties)  \
# 0                              EQUITY_UK
# 1                              EQUITY_UK
# 2                              EQUITY_UK
# 3                              EQUITY_UK
# 4                              EQUITY_UK
# 5                              EQUITY_UK
# 6                              EQUITY_UK
# 7                              EQUITY_UK
# 8                              EQUITY_UK
# 9                              EQUITY_UK
# 10                             EQUITY_UK
# 11                             EQUITY_UK
# 12                             EQUITY_UK
# 13                             EQUITY_UK
# 14                             EQUITY_UK
# 15                             EQUITY_UK
# 16                             EQUITY_UK
# 17                             EQUITY_UK
# 18                             EQUITY_UK
# 19                             EQUITY_UK
#
#    SourcePortfolioScope(default-Properties)  ResultantHolding  \
# 0                         3a46-ede9-c627-1e          120000.0
# 1                         3a46-ede9-c627-1e          132000.0
# 2                         3a46-ede9-c627-1e           60000.0
# 3                         3a46-ede9-c627-1e          120000.0
# 4                         3a46-ede9-c627-1e          150000.0
# 5                         3a46-ede9-c627-1e          300000.0
# 6                         3a46-ede9-c627-1e          100000.0
# 7                         3a46-ede9-c627-1e          200000.0
# 8                         3a46-ede9-c627-1e           20000.0
# 9                         3a46-ede9-c627-1e           40000.0
# 10                        3a46-ede9-c627-1e               NaN
# 11                        3a46-ede9-c627-1e          180000.0
# 12                        3a46-ede9-c627-1e          360000.0
# 13                        3a46-ede9-c627-1e            8000.0
# 14                        3a46-ede9-c627-1e           80000.0
# 15                        3a46-ede9-c627-1e          160000.0
# 16                        3a46-ede9-c627-1e          450000.0
# 17                        3a46-ede9-c627-1e          900000.0
# 18                        3a46-ede9-c627-1e           35000.0
# 19                        3a46-ede9-c627-1e           70000.0
#
#         InstrumentName TransactionStatus                    EntryDateTime  \
# 0                Aviva            Active 2021-12-24 13:47:15.614122+00:00
# 1                Aviva            Active 2021-12-24 13:47:15.614122+00:00
# 2                  BHP            Active 2021-12-24 13:47:15.614122+00:00
# 3                  BHP            Active 2021-12-24 13:47:15.614122+00:00
# 4             Barclays            Active 2021-12-24 13:47:15.614122+00:00
# 5             Barclays            Active 2021-12-24 13:47:15.614122+00:00
# 6                   BP            Active 2021-12-24 13:47:15.614122+00:00
# 7                   BP            Active 2021-12-24 13:47:15.614122+00:00
# 8                 HSBC            Active 2021-12-24 13:47:15.614122+00:00
# 9                 HSBC            Active 2021-12-24 13:47:15.614122+00:00
# 10                 GBP            Active 2021-12-24 13:47:15.614122+00:00
# 11           Morrisons            Active 2021-12-24 13:47:15.614122+00:00
# 12           Morrisons            Active 2021-12-24 13:47:15.614122+00:00
# 13               Tesco            Active 2021-12-24 13:47:15.614122+00:00
# 14           Rightmove            Active 2021-12-24 13:47:15.614122+00:00
# 15           Rightmove            Active 2021-12-24 13:47:15.614122+00:00
# 16            vodafone            Active 2021-12-24 13:47:15.614122+00:00
# 17            vodafone            Active 2021-12-24 13:47:15.614122+00:00
# 18  Anglo American plc            Active 2021-12-24 13:47:15.614122+00:00
# 19  Anglo American plc            Active 2021-12-24 13:47:15.614122+00:00
#
#    RealisedGainLoss InstrumentCurrency
# 0                []                NaN
# 1                []                NaN
# 2                []                NaN
# 3                []                NaN
# 4                []                NaN
# 5                []                NaN
# 6                []                NaN
# 7                []                NaN
# 8                []                NaN
# 9                []                NaN
# 10               []                GBP
# 11               []                NaN
# 12               []                NaN
# 13               []                NaN
# 14               []                NaN
# 15               []                NaN
# 16               []                NaN
# 17               []                NaN
# 18               []                NaN
# 19               []                NaN

# %% [markdown]
# ## 4) Cancel one of the Aviva transactions

# %%
cancel_response = txn_port_api.cancel_transactions(
    scope=scope, code=portfolio_code, transaction_ids=['trd_0001']
)

# %%
first_cancel_datetime = cancel_response.as_at
print(f'The first cancel datetime request is: {first_cancel_datetime}')
# Out:
# The first cancel datetime request is: 2021-12-24 13:47:17.189525+00:00

# %% [markdown]
# ## 5) Cancel two of the BHP transactions

# %%
cancel_response = txn_port_api.cancel_transactions(
    scope=scope, code=portfolio_code, transaction_ids=['trd_0003', 'trd_0004']
)

second_cancel_datetime = cancel_response.as_at
print(f'The second cancel datetime request is: {first_cancel_datetime}')
# Out:
# The second cancel datetime request is: 2021-12-24 13:47:17.189525+00:00

# %% [markdown]
# ## 6) Check holdings again

# %%
response = txn_port_api.get_holdings(
    scope=scope, code=portfolio_code, property_keys=['Instrument/default/Name']
)

hodlings_df = lusid_response_to_data_frame(
    response, rename_properties=True, column_name_mapping=get_holdings_json_mapping
)

holdings_df
# Out:
#    instrument_scope LusidInstrumentId SubHoldingKeys      InstrumentName  \
# 0           default     LUID_00003D60             {}               Aviva
# 1           default     LUID_00003D61             {}                 BHP
# 2           default     LUID_00003D68             {}            Barclays
# 3           default     LUID_00003D67             {}                  BP
# 4           default     LUID_00003D62             {}                HSBC
# 5           default           CCY_GBP             {}                 GBP
# 6           default     LUID_00003D63             {}           Morrisons
# 7           default     LUID_00003D5Y             {}               Tesco
# 8           default     LUID_00003D65             {}           Rightmove
# 9           default     LUID_00003D5Z             {}            vodafone
# 10          default     LUID_00003D66             {}  Anglo American plc
#
#    SourcePortfolioId SourcePortfolioScope(default-Properties) HoldingType  \
# 0          EQUITY_UK                        3a46-ede9-c627-1e           P
# 1          EQUITY_UK                        3a46-ede9-c627-1e           P
# 2          EQUITY_UK                        3a46-ede9-c627-1e           P
# 3          EQUITY_UK                        3a46-ede9-c627-1e           P
# 4          EQUITY_UK                        3a46-ede9-c627-1e           P
# 5          EQUITY_UK                        3a46-ede9-c627-1e           B
# 6          EQUITY_UK                        3a46-ede9-c627-1e           P
# 7          EQUITY_UK                        3a46-ede9-c627-1e           P
# 8          EQUITY_UK                        3a46-ede9-c627-1e           P
# 9          EQUITY_UK                        3a46-ede9-c627-1e           P
# 10         EQUITY_UK                        3a46-ede9-c627-1e           P
#
#         Units  SettledUnits  Amount-Cost Currency-Cost  \
# 0    132000.0      132000.0     660000.0           GBP
# 1    120000.0      120000.0    2160000.0           GBP
# 2    300000.0      300000.0     600000.0           GBP
# 3    200000.0      200000.0    1000000.0           GBP
# 4     40000.0       40000.0     240000.0           GBP
# 5   3260000.0     3260000.0    3260000.0           GBP
# 6    360000.0      360000.0     720000.0           GBP
# 7     12000.0       12000.0     100000.0           GBP
# 8    160000.0      160000.0     960000.0           GBP
# 9    900000.0      900000.0     900000.0           GBP
# 10    70000.0       70000.0    1400000.0           GBP
#
#     Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 0                  660000.0                       GBP      GBP
# 1                 2160000.0                       GBP      GBP
# 2                  600000.0                       GBP      GBP
# 3                 1000000.0                       GBP      GBP
# 4                  240000.0                       GBP      GBP
# 5                 3260000.0                       GBP      GBP
# 6                  720000.0                       GBP      GBP
# 7                  100000.0                       GBP      GBP
# 8                  960000.0                       GBP      GBP
# 9                  900000.0                       GBP      GBP
# 10                1400000.0                       GBP      GBP

# %%
as_at_time = first_cancel_datetime - timedelta(milliseconds=10)

print(f'The current datetime is {datetime.now(tz=pytz.UTC)}...')
print(f'Getting holdings as at {as_at_time}...')
print(f'This is just the first cancellation datetime of {first_cancel_datetime}')
# Out:
# The current datetime is 2021-12-24 13:47:18.258373+00:00...
# Getting holdings as at 2021-12-24 13:47:17.179525+00:00...
# This is just the first cancellation datetime of 2021-12-24 13:47:17.189525+00:00

# %%
response = txn_port_api.get_holdings(
    scope=scope, code=portfolio_code, property_keys=['Instrument/default/Name'], as_at=as_at_time
)

holdings_df = lusid_response_to_data_frame(
    response, rename_properties=False, column_name_mapping=get_holdings_json_mapping
)

holdings_df
# Out:
#    instrument_scope LusidInstrumentId SubHoldingKeys  \
# 0           default     LUID_00003D60             {}
# 1           default     LUID_00003D61             {}
# 2           default     LUID_00003D68             {}
# 3           default     LUID_00003D67             {}
# 4           default     LUID_00003D62             {}
# 5           default           CCY_GBP             {}
# 6           default     LUID_00003D63             {}
# 7           default     LUID_00003D5Y             {}
# 8           default     LUID_00003D65             {}
# 9           default     LUID_00003D5Z             {}
# 10          default     LUID_00003D66             {}
#
#    properties.Instrument/default/Name.key  \
# 0                 Instrument/default/Name
# 1                 Instrument/default/Name
# 2                 Instrument/default/Name
# 3                 Instrument/default/Name
# 4                 Instrument/default/Name
# 5                 Instrument/default/Name
# 6                 Instrument/default/Name
# 7                 Instrument/default/Name
# 8                 Instrument/default/Name
# 9                 Instrument/default/Name
# 10                Instrument/default/Name
#
#    properties.Instrument/default/Name.value.label_value  \
# 0                                               Aviva
# 1                                                 BHP
# 2                                            Barclays
# 3                                                  BP
# 4                                                HSBC
# 5                                                 GBP
# 6                                           Morrisons
# 7                                               Tesco
# 8                                           Rightmove
# 9                                            vodafone
# 10                                 Anglo American plc
#
#    properties.Instrument/default/Name.effective_from  \
# 0                          0001-01-01 00:00:00+00:00
# 1                          0001-01-01 00:00:00+00:00
# 2                          0001-01-01 00:00:00+00:00
# 3                          0001-01-01 00:00:00+00:00
# 4                          0001-01-01 00:00:00+00:00
# 5                          0001-01-01 00:00:00+00:00
# 6                          0001-01-01 00:00:00+00:00
# 7                          0001-01-01 00:00:00+00:00
# 8                          0001-01-01 00:00:00+00:00
# 9                          0001-01-01 00:00:00+00:00
# 10                         0001-01-01 00:00:00+00:00
#
#    properties.Holding/default/SourcePortfolioId.key  \
# 0                 Holding/default/SourcePortfolioId
# 1                 Holding/default/SourcePortfolioId
# 2                 Holding/default/SourcePortfolioId
# 3                 Holding/default/SourcePortfolioId
# 4                 Holding/default/SourcePortfolioId
# 5                 Holding/default/SourcePortfolioId
# 6                 Holding/default/SourcePortfolioId
# 7                 Holding/default/SourcePortfolioId
# 8                 Holding/default/SourcePortfolioId
# 9                 Holding/default/SourcePortfolioId
# 10                Holding/default/SourcePortfolioId
#
#    properties.Holding/default/SourcePortfolioId.value.label_value  \
# 0                                           EQUITY_UK
# 1                                           EQUITY_UK
# 2                                           EQUITY_UK
# 3                                           EQUITY_UK
# 4                                           EQUITY_UK
# 5                                           EQUITY_UK
# 6                                           EQUITY_UK
# 7                                           EQUITY_UK
# 8                                           EQUITY_UK
# 9                                           EQUITY_UK
# 10                                          EQUITY_UK
#
#    properties.Holding/default/SourcePortfolioId.effective_from  \
# 0                           0001-01-01 00:00:00+00:00
# 1                           0001-01-01 00:00:00+00:00
# 2                           0001-01-01 00:00:00+00:00
# 3                           0001-01-01 00:00:00+00:00
# 4                           0001-01-01 00:00:00+00:00
# 5                           0001-01-01 00:00:00+00:00
# 6                           0001-01-01 00:00:00+00:00
# 7                           0001-01-01 00:00:00+00:00
# 8                           0001-01-01 00:00:00+00:00
# 9                           0001-01-01 00:00:00+00:00
# 10                          0001-01-01 00:00:00+00:00
#
#    properties.Holding/default/SourcePortfolioScope.key  \
# 0                Holding/default/SourcePortfolioScope
# 1                Holding/default/SourcePortfolioScope
# 2                Holding/default/SourcePortfolioScope
# 3                Holding/default/SourcePortfolioScope
# 4                Holding/default/SourcePortfolioScope
# 5                Holding/default/SourcePortfolioScope
# 6                Holding/default/SourcePortfolioScope
# 7                Holding/default/SourcePortfolioScope
# 8                Holding/default/SourcePortfolioScope
# 9                Holding/default/SourcePortfolioScope
# 10               Holding/default/SourcePortfolioScope
#
#    properties.Holding/default/SourcePortfolioScope.value.label_value  \
# 0                                   3a46-ede9-c627-1e
# 1                                   3a46-ede9-c627-1e
# 2                                   3a46-ede9-c627-1e
# 3                                   3a46-ede9-c627-1e
# 4                                   3a46-ede9-c627-1e
# 5                                   3a46-ede9-c627-1e
# 6                                   3a46-ede9-c627-1e
# 7                                   3a46-ede9-c627-1e
# 8                                   3a46-ede9-c627-1e
# 9                                   3a46-ede9-c627-1e
# 10                                  3a46-ede9-c627-1e
#
#    properties.Holding/default/SourcePortfolioScope.effective_from HoldingType  \
# 0                           0001-01-01 00:00:00+00:00                       P
# 1                           0001-01-01 00:00:00+00:00                       P
# 2                           0001-01-01 00:00:00+00:00                       P
# 3                           0001-01-01 00:00:00+00:00                       P
# 4                           0001-01-01 00:00:00+00:00                       P
# 5                           0001-01-01 00:00:00+00:00                       B
# 6                           0001-01-01 00:00:00+00:00                       P
# 7                           0001-01-01 00:00:00+00:00                       P
# 8                           0001-01-01 00:00:00+00:00                       P
# 9                           0001-01-01 00:00:00+00:00                       P
# 10                          0001-01-01 00:00:00+00:00                       P
#
#         Units  SettledUnits  Amount-Cost Currency-Cost  \
# 0    132000.0      132000.0     660000.0           GBP
# 1    120000.0      120000.0    2160000.0           GBP
# 2    300000.0      300000.0     600000.0           GBP
# 3    200000.0      200000.0    1000000.0           GBP
# 4     40000.0       40000.0     240000.0           GBP
# 5   3260000.0     3260000.0    3260000.0           GBP
# 6    360000.0      360000.0     720000.0           GBP
# 7     12000.0       12000.0     100000.0           GBP
# 8    160000.0      160000.0     960000.0           GBP
# 9    900000.0      900000.0     900000.0           GBP
# 10    70000.0       70000.0    1400000.0           GBP
#
#     Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 0                  660000.0                       GBP      GBP
# 1                 2160000.0                       GBP      GBP
# 2                  600000.0                       GBP      GBP
# 3                 1000000.0                       GBP      GBP
# 4                  240000.0                       GBP      GBP
# 5                 3260000.0                       GBP      GBP
# 6                  720000.0                       GBP      GBP
# 7                  100000.0                       GBP      GBP
# 8                  960000.0                       GBP      GBP
# 9                  900000.0                       GBP      GBP
# 10                1400000.0                       GBP      GBP
