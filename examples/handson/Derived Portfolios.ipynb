# %% [markdown]
# # Derived Portfolios

# %%
import os
import json
from datetime import datetime, timedelta
import pytz

import lusid
import lusid.models as models
from lusid.exceptions import ApiException
from lusid.utilities import ApiClientFactory
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.cocoon.seed_sample_data import seed_data
from lusidtools.cocoon.utilities import create_scope_id

import pandas as pd

pd.set_option('display.max_columns', None)

secrets_path = '/Users/msingh/Projects/lusidws/secrets.json'

api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name='LusidJupyterNotebook'
)

# %%
with open(r'config/build_transactions_mapping.json') as mappings_file:
    build_transactions_json_mapping = json.load(mappings_file)
    
with open(r'config/get_holdings_mapping.json') as mappings_file:
    get_holdings_json_mapping = json.load(mappings_file)

# %% [markdown]
# ## 1) Load default transactions into a new scope

# %%
scope = 'notebook-derived-portfolios'
portfolio_code = 'EQUITY-UK' + '-' + create_scope_id()
portfolio_code
# Out:
# 'EQUITY-UK-3a46-f87c-1350-d6'

# %%
transactions_file = r'data/derived/equity_transactions.csv'
transactions_df = pd.read_csv(transactions_file)
transactions_df['portfolio_code'] = portfolio_code

# %%
seed_data_response = seed_data(
    api_factory,
    ['portfolios', 'instruments', 'transactions'],
    scope,
    transactions_df,
    'DataFrame',
)

# %%
transactions_portfolio_api = api_factory.build(lusid.api.TransactionPortfoliosApi)
derived_portfolios_api = api_factory.build(lusid.api.DerivedTransactionPortfoliosApi)

# %% [markdown]
# ## 2) Lets check our holdings

# %%
response = transactions_portfolio_api.get_holdings(
    scope=scope, code=portfolio_code, property_keys=['Instrument/default/Name']
)

holdings_df = lusid_response_to_data_frame(
    response, rename_properties=True, column_name_mapping=get_holdings_json_mapping
)
holdings_df
# Out:
#    instrument_scope LusidInstrumentId SubHoldingKeys      InstrumentName  \
# 0           default     LUID_00003D60             {}               Aviva
# 1           default     LUID_00003D61             {}                 BHP
# 2           default     LUID_00003D68             {}            Barclays
# 3           default     LUID_00003D67             {}                  BP
# 4           default     LUID_00003D62             {}                HSBC
# 5           default           CCY_GBP             {}                 GBP
# 6           default     LUID_00003D63             {}           Morrisons
# 7           default     LUID_00003D5Y             {}               Tesco
# 8           default     LUID_00003D65             {}           Rightmove
# 9           default     LUID_00003D5Z             {}            vodafone
# 10          default     LUID_00003D66             {}  Anglo American plc
#
#               SourcePortfolioId SourcePortfolioScope(default-Properties)  \
# 0   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 1   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 2   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 3   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 4   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 5   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 6   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 7   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 8   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 9   EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
# 10  EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
#
#    HoldingType      Units  SettledUnits  Amount-Cost Currency-Cost  \
# 0            P   132000.0      132000.0     660000.0           GBP
# 1            P   120000.0      120000.0    2160000.0           GBP
# 2            P   300000.0      300000.0     600000.0           GBP
# 3            P   200000.0      200000.0    1000000.0           GBP
# 4            P    40000.0       40000.0     240000.0           GBP
# 5            B  3260000.0     3260000.0    3260000.0           GBP
# 6            P   360000.0      360000.0     720000.0           GBP
# 7            P    12000.0       12000.0     100000.0           GBP
# 8            P   160000.0      160000.0     960000.0           GBP
# 9            P   900000.0      900000.0     900000.0           GBP
# 10           P    70000.0       70000.0    1400000.0           GBP
#
#     Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 0                  660000.0                       GBP      GBP
# 1                 2160000.0                       GBP      GBP
# 2                  600000.0                       GBP      GBP
# 3                 1000000.0                       GBP      GBP
# 4                  240000.0                       GBP      GBP
# 5                 3260000.0                       GBP      GBP
# 6                  720000.0                       GBP      GBP
# 7                  100000.0                       GBP      GBP
# 8                  960000.0                       GBP      GBP
# 9                  900000.0                       GBP      GBP
# 10                1400000.0                       GBP      GBP

# %% [markdown]
# ## 3) What transactions make up our Barclays holdings?

# %%
build_transactions_response = transactions_portfolio_api.build_transactions(
    scope=scope,
    code=portfolio_code,
    transaction_query_parameters=models.TransactionQueryParameters(
        start_date='2020-01-01', end_date='2021-12-31'
    ),
    property_keys=['Instrument/default/Name']
)

build_transactions_df = lusid_response_to_data_frame(
    build_transactions_response,
    rename_properties=True,
    column_name_mapping=build_transactions_json_mapping,
)

build_transactions_df.query("InstrumentName == 'Barclays'")
# Out:
#   TransactionId TransactionType TransactionTypeDesc ClientId instrument_scope  \
# 4      trd_0005             Buy            Purchase  EQ_1236          default
# 5      trd_0006             Buy            Purchase  EQ_1236          default
#
#   LusidInstrumentId           TransactionDate            SettlementDate  \
# 4     LUID_00003D68 2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00
# 5     LUID_00003D68 2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00
#
#       Units  TransactionAmount  Price PriceType  TotalConsideration  \
# 4  150000.0           300000.0    2.0     Price            300000.0
# 5  150000.0           300000.0    2.0     Price            300000.0
#
#   TotalConsiderationCurrency  ExchangeRate  TransactionToPortfolioRate  \
# 4                        GBP           1.0                         0.0
# 5                        GBP           1.0                         0.0
#
#   TransactionCurrency strategy(notebook-derived-portfolios-Properties)  \
# 4                 GBP                                     ftse_tracker
# 5                 GBP                                     ftse_tracker
#
#   SourcePortfolioId(default-Properties)  \
# 4           EQUITY-UK-3a46-f87c-1350-d6
# 5           EQUITY-UK-3a46-f87c-1350-d6
#
#   SourcePortfolioScope(default-Properties)  ResultantHolding InstrumentName  \
# 4              notebook-derived-portfolios          150000.0       Barclays
# 5              notebook-derived-portfolios          300000.0       Barclays
#
#   TransactionStatus                    EntryDateTime RealisedGainLoss  \
# 4            Active 2021-12-24 15:02:55.463113+00:00               []
# 5            Active 2021-12-24 15:02:55.463113+00:00               []
#
#   InstrumentCurrency
# 4                NaN
# 5                NaN

# %% [markdown]
# ## 4) Create a derived portfolio

# %%
new_scope = 'TempReporting' + '-' + scope
print(f'The scope we will use for the derived portfolios: {new_scope}')
# Out:
# The scope we will use for the derived portfolios: TempReporting-notebook-derived-portfolios

# %%
try:
    derived_portfolios_api.create_derived_portfolio(scope=new_scope, 
        create_derived_transaction_portfolio_request = models.CreateDerivedTransactionPortfolioRequest(
            display_name=portfolio_code,
            description='Reporting Portfolio',
            code=portfolio_code,
            parent_portfolio_id=models.ResourceId(scope=scope, code=portfolio_code),
            created='2020-01-01',
            corporate_action_source_id=None,
            accounting_method=None,
            sub_holding_keys=None
        ))

except ApiException as e:
    print(json.loads(e.body)['name'])
    print(json.loads(e.body)['title'])

# %%
response = transactions_portfolio_api.get_transactions(scope=new_scope, code=portfolio_code)
transactions_df = lusid_response_to_data_frame(
    response,
    rename_properties=True,
    column_name_mapping=build_transactions_json_mapping
)
transactions_df
# Out:
#    TransactionId TransactionType ClientId instrument_scope LusidInstrumentId  \
# 0       trd_0001             Buy  EQ_1234          default     LUID_00003D60
# 1       trd_0002             Buy  EQ_1234          default     LUID_00003D60
# 2       trd_0003             Buy  EQ_1235          default     LUID_00003D61
# 3       trd_0004             Buy  EQ_1235          default     LUID_00003D61
# 4       trd_0005             Buy  EQ_1236          default     LUID_00003D68
# 5       trd_0006             Buy  EQ_1236          default     LUID_00003D68
# 6       trd_0007             Buy  EQ_1237          default     LUID_00003D67
# 7       trd_0008             Buy  EQ_1237          default     LUID_00003D67
# 8       trd_0009             Buy  EQ_1238          default     LUID_00003D62
# 9       trd_0010             Buy  EQ_1238          default     LUID_00003D62
# 10      trd_0021         FundsIn      NaN          default           CCY_GBP
# 11      trd_0011             Buy  EQ_1239          default     LUID_00003D63
# 12      trd_0012             Buy  EQ_1239          default     LUID_00003D63
# 13      trd_0022             Buy  EQ_1240          default     LUID_00003D5Y
# 14      trd_0015             Buy  EQ_1241          default     LUID_00003D65
# 15      trd_0016             Buy  EQ_1241          default     LUID_00003D65
# 16      trd_0017             Buy  EQ_1242          default     LUID_00003D5Z
# 17      trd_0018             Buy  EQ_1242          default     LUID_00003D5Z
# 18      trd_0019             Buy  EQ_1243          default     LUID_00003D66
# 19      trd_0020             Buy  EQ_1243          default     LUID_00003D66
# 20      trd_0014             Buy  EQ_1240          default     LUID_00003D5Y
#
#              TransactionDate            SettlementDate       Units  Price  \
# 0  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00    120000.0    5.0
# 1  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00     12000.0    5.0
# 2  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00     60000.0   18.0
# 3  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00     60000.0   18.0
# 4  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00    150000.0    2.0
# 5  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00    150000.0    2.0
# 6  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00    100000.0    5.0
# 7  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00    100000.0    5.0
# 8  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00     20000.0    6.0
# 9  2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00     20000.0    6.0
# 10 2020-01-02 00:00:00+00:00 2020-01-04 00:00:00+00:00  12000000.0    1.0
# 11 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00    180000.0    2.0
# 12 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00    180000.0    2.0
# 13 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00      8000.0    8.0
# 14 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00     80000.0    6.0
# 15 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00     80000.0    6.0
# 16 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00    450000.0    1.0
# 17 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00    450000.0    1.0
# 18 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00     35000.0   20.0
# 19 2020-01-15 00:00:00+00:00 2020-01-17 00:00:00+00:00     35000.0   20.0
# 20 2020-01-16 00:00:00+00:00 2020-01-18 00:00:00+00:00      4000.0    9.0
#
#    PriceType  TotalConsideration TotalConsiderationCurrency  ExchangeRate  \
# 0      Price            600000.0                        GBP           1.0
# 1      Price             60000.0                        GBP           1.0
# 2      Price           1080000.0                        GBP           1.0
# 3      Price           1080000.0                        GBP           1.0
# 4      Price            300000.0                        GBP           1.0
# 5      Price            300000.0                        GBP           1.0
# 6      Price            500000.0                        GBP           1.0
# 7      Price            500000.0                        GBP           1.0
# 8      Price            120000.0                        GBP           1.0
# 9      Price            120000.0                        GBP           1.0
# 10     Price          12000000.0                        GBP           1.0
# 11     Price            360000.0                        GBP           1.0
# 12     Price            360000.0                        GBP           1.0
# 13     Price             64000.0                        GBP           1.0
# 14     Price            480000.0                        GBP           1.0
# 15     Price            480000.0                        GBP           1.0
# 16     Price            450000.0                        GBP           1.0
# 17     Price            450000.0                        GBP           1.0
# 18     Price            700000.0                        GBP           1.0
# 19     Price            700000.0                        GBP           1.0
# 20     Price             36000.0                        GBP           1.0
#
#    TransactionCurrency strategy(notebook-derived-portfolios-Properties)  \
# 0                  GBP                                     ftse_tracker
# 1                  GBP                                     ftse_tracker
# 2                  GBP                                     ftse_tracker
# 3                  GBP                                     ftse_tracker
# 4                  GBP                                     ftse_tracker
# 5                  GBP                                     ftse_tracker
# 6                  GBP                                     ftse_tracker
# 7                  GBP                                     ftse_tracker
# 8                  GBP                                     ftse_tracker
# 9                  GBP                                     ftse_tracker
# 10                 GBP                                     ftse_tracker
# 11                 GBP                                     ftse_tracker
# 12                 GBP                                     ftse_tracker
# 13                 GBP                                     ftse_tracker
# 14                 GBP                                     ftse_tracker
# 15                 GBP                                     ftse_tracker
# 16                 GBP                                     ftse_tracker
# 17                 GBP                                     ftse_tracker
# 18                 GBP                                     ftse_tracker
# 19                 GBP                                     ftse_tracker
# 20                 GBP                                     ftse_tracker
#
#    SourcePortfolioId(default-Properties)  \
# 0            EQUITY-UK-3a46-f87c-1350-d6
# 1            EQUITY-UK-3a46-f87c-1350-d6
# 2            EQUITY-UK-3a46-f87c-1350-d6
# 3            EQUITY-UK-3a46-f87c-1350-d6
# 4            EQUITY-UK-3a46-f87c-1350-d6
# 5            EQUITY-UK-3a46-f87c-1350-d6
# 6            EQUITY-UK-3a46-f87c-1350-d6
# 7            EQUITY-UK-3a46-f87c-1350-d6
# 8            EQUITY-UK-3a46-f87c-1350-d6
# 9            EQUITY-UK-3a46-f87c-1350-d6
# 10           EQUITY-UK-3a46-f87c-1350-d6
# 11           EQUITY-UK-3a46-f87c-1350-d6
# 12           EQUITY-UK-3a46-f87c-1350-d6
# 13           EQUITY-UK-3a46-f87c-1350-d6
# 14           EQUITY-UK-3a46-f87c-1350-d6
# 15           EQUITY-UK-3a46-f87c-1350-d6
# 16           EQUITY-UK-3a46-f87c-1350-d6
# 17           EQUITY-UK-3a46-f87c-1350-d6
# 18           EQUITY-UK-3a46-f87c-1350-d6
# 19           EQUITY-UK-3a46-f87c-1350-d6
# 20           EQUITY-UK-3a46-f87c-1350-d6
#
#    SourcePortfolioScope(default-Properties)                    EntryDateTime  \
# 0               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 1               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 2               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 3               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 4               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 5               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 6               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 7               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 8               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 9               notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 10              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 11              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 12              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 13              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 14              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 15              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 16              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 17              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 18              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 19              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
# 20              notebook-derived-portfolios 2021-12-24 15:02:55.463113+00:00
#
#    InstrumentCurrency
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                GBP
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN

# %%
cancel_response = transactions_portfolio_api.cancel_transactions(
    scope=new_scope, code=portfolio_code, transaction_ids=['trd_0006']
)

# %% [markdown]
# ## 6) Check holdings on the primary and the derived portfolio

# %%
response = transactions_portfolio_api.get_holdings(
    scope=scope, code=portfolio_code, property_keys=['Instrument/default/Name']
)

holdings_df = lusid_response_to_data_frame(
    response, rename_properties=True, column_name_mapping=get_holdings_json_mapping
)

holdings_df.query("InstrumentName == 'Barclays'")
# Out:
#   instrument_scope LusidInstrumentId SubHoldingKeys InstrumentName  \
# 2          default     LUID_00003D68             {}       Barclays
#
#              SourcePortfolioId SourcePortfolioScope(default-Properties)  \
# 2  EQUITY-UK-3a46-f87c-1350-d6              notebook-derived-portfolios
#
#   HoldingType     Units  SettledUnits  Amount-Cost Currency-Cost  \
# 2           P  300000.0      300000.0     600000.0           GBP
#
#    Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 2                 600000.0                       GBP      GBP

# %%
response = transactions_portfolio_api.get_holdings(
    scope=new_scope, code=portfolio_code, property_keys=['Instrument/default/Name']
)

holdings_df = lusid_response_to_data_frame(
    response, rename_properties=True, column_name_mapping=get_holdings_json_mapping
)

holdings_df.query("InstrumentName == 'Barclays'")
# Out:
#   instrument_scope LusidInstrumentId SubHoldingKeys InstrumentName  \
# 2          default     LUID_00003D68             {}       Barclays
#
#              SourcePortfolioId   SourcePortfolioScope(default-Properties)  \
# 2  EQUITY-UK-3a46-f87c-1350-d6  TempReporting-notebook-derived-portfolios
#
#   HoldingType     Units  SettledUnits  Amount-Cost Currency-Cost  \
# 2           P  150000.0      150000.0     300000.0           GBP
#
#    Amount-CostPortfolioCcy Currenct-CostPortfolioCcy currency
# 2                 300000.0                       GBP      GBP
