# %% [markdown]
# # Generating IBOR extract

# %% [markdown]
# ## Setup

# %%
import os
import json
from datetime import datetime, timedelta
import pytz

import lusid
import lusid.models as models
from lusid.exceptions import ApiException
from lusid.utilities import ApiClientFactory
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.cocoon.seed_sample_data import seed_data
from lusidtools.cocoon.utilities import create_scope_id

import pandas as pd

pd.set_option('display.max_columns', None)

secrets_path = '/Users/msingh/Projects/lusidws/secrets.json'

api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name='LusidJupyterNotebook'
)

# %%
with open(r'config/build_transactions_mapping.json') as mapping_file:
    build_txn_json_mappings = json.load(mapping_file)

# %% [markdown]
# ## Load transactions into a new scope

# %%
scope = create_scope_id()
portfolio_code = "EQUITY_UK"

# %%
transactions_file = r'data/equity_transactions.csv'
transactions_df = pd.read_csv(transactions_file)
transactions_df['portfolio_code'] = portfolio_code

# %%
seed_data_response = seed_data(api_factory,
                              ['portfolios', 'instruments', 'transactions'],
                              scope,
                              transactions_file,
                              'csv')

# %% [markdown]
# ## Get Holdings

# %%
txn_port_api = api_factory.build(lusid.api.TransactionPortfoliosApi)

# %%
holdings_response = txn_port_api.get_holdings(
    scope=scope,
    code=portfolio_code,
    property_keys=['Instrument/default/Name']
)

# %%
lusid_response_to_data_frame(
    holdings_response,
    rename_properties=True
).head(10)
# Out:
#   instrument_scope instrument_uid sub_holding_keys Name(default-Properties)  \
# 0          default  LUID_00003D60               {}                    Aviva
# 1          default  LUID_00003D61               {}                      BHP
# 2          default  LUID_00003D68               {}                 Barclays
# 3          default  LUID_00003D67               {}                       BP
# 4          default  LUID_00003D62               {}                     HSBC
# 5          default        CCY_GBP               {}                      GBP
# 6          default  LUID_00003D63               {}                Morrisons
# 7          default  LUID_00003D5Y               {}                    Tesco
# 8          default  LUID_00003D65               {}                Rightmove
# 9          default  LUID_00003D5Z               {}                 vodafone
#
#   SourcePortfolioId(default-Properties)  \
# 0                             EQUITY_UK
# 1                             EQUITY_UK
# 2                             EQUITY_UK
# 3                             EQUITY_UK
# 4                             EQUITY_UK
# 5                             EQUITY_UK
# 6                             EQUITY_UK
# 7                             EQUITY_UK
# 8                             EQUITY_UK
# 9                             EQUITY_UK
#
#   SourcePortfolioScope(default-Properties) holding_type      units  \
# 0                        3a48-faea-3ca5-56            P   132000.0
# 1                        3a48-faea-3ca5-56            P   120000.0
# 2                        3a48-faea-3ca5-56            P   300000.0
# 3                        3a48-faea-3ca5-56            P   200000.0
# 4                        3a48-faea-3ca5-56            P    40000.0
# 5                        3a48-faea-3ca5-56            B  3260000.0
# 6                        3a48-faea-3ca5-56            P   360000.0
# 7                        3a48-faea-3ca5-56            P    12000.0
# 8                        3a48-faea-3ca5-56            P   160000.0
# 9                        3a48-faea-3ca5-56            P   900000.0
#
#    settled_units  cost.amount cost.currency  cost_portfolio_ccy.amount  \
# 0       132000.0     660000.0           GBP                   660000.0
# 1       120000.0    2160000.0           GBP                  2160000.0
# 2       300000.0     600000.0           GBP                   600000.0
# 3       200000.0    1000000.0           GBP                  1000000.0
# 4        40000.0     240000.0           GBP                   240000.0
# 5      3260000.0    3260000.0           GBP                  3260000.0
# 6       360000.0     720000.0           GBP                   720000.0
# 7        12000.0     100000.0           GBP                   100000.0
# 8       160000.0     960000.0           GBP                   960000.0
# 9       900000.0     900000.0           GBP                   900000.0
#
#   cost_portfolio_ccy.currency currency
# 0                         GBP      GBP
# 1                         GBP      GBP
# 2                         GBP      GBP
# 3                         GBP      GBP
# 4                         GBP      GBP
# 5                         GBP      GBP
# 6                         GBP      GBP
# 7                         GBP      GBP
# 8                         GBP      GBP
# 9                         GBP      GBP

# %% [markdown]
# ## Holdings for a specific date and time

# %%
holdings_response_fifth_jan = txn_port_api.get_holdings(
    scope=scope,
    code=portfolio_code,
    effective_at="2020-01-05T12:30:00Z",
    property_keys=["Instrument/default/Name"]
)

# %%
holdings_fifth_jan = lusid_response_to_data_frame(holdings_response_fifth_jan, rename_properties=True)

column_rename = {
    "instrument_uid": "luid",
    "Name(default-Properties)": "instrumentName",
    "holding_type": "holdingType",
    "units": "units",
    "settled_units": "settledUnits",
    "cost.amount": "costAmount",
    "cost.currency": "costCurrency",
    "cost_portfolio_ccy.currency": "portfolioCurrency"
}

holdings_fifth_jan = holdings_fifth_jan.rename(columns = column_rename)[column_rename.values()].copy()
display(holdings_fifth_jan.query("instrumentName == 'Barclays'"))
# Out:
#             luid instrumentName holdingType     units  settledUnits  \
# 2  LUID_00003D68       Barclays           P  300000.0      300000.0
#
#    costAmount costCurrency portfolioCurrency
# 2    600000.0          GBP               GBP

# %% [markdown]
# ## What transactions produced my holdings?

# %%
build_transactions_response = txn_port_api.build_transactions(
    scope=scope,
    code=portfolio_code,
    property_keys=['Instrument/default/Name'],
    transaction_query_parameters = models.TransactionQueryParameters(start_date="2020-01-01",
                                                                                   end_date="2020-12-31")
)

# %%
columns = ["TransactionId",
"TransactionType",
"LusidInstrumentId",
"InstrumentName",
"SettlementDate",
"Price",
"Units",
"ResultantHolding"]

transactions_df = lusid_response_to_data_frame(build_transactions_response, 
                                               column_name_mapping=build_txn_json_mappings,
                                                rename_properties=True)
transactions_df = transactions_df[columns]
transactions_df
# Out:
#    TransactionId TransactionType LusidInstrumentId      InstrumentName  \
# 0       trd_0001             Buy     LUID_00003D60               Aviva
# 1       trd_0002             Buy     LUID_00003D60               Aviva
# 2       trd_0003             Buy     LUID_00003D61                 BHP
# 3       trd_0004             Buy     LUID_00003D61                 BHP
# 4       trd_0005             Buy     LUID_00003D68            Barclays
# 5       trd_0006             Buy     LUID_00003D68            Barclays
# 6       trd_0007             Buy     LUID_00003D67                  BP
# 7       trd_0008             Buy     LUID_00003D67                  BP
# 8       trd_0009             Buy     LUID_00003D62                HSBC
# 9       trd_0010             Buy     LUID_00003D62                HSBC
# 10      trd_0021         FundsIn           CCY_GBP                 GBP
# 11      trd_0011             Buy     LUID_00003D63           Morrisons
# 12      trd_0012             Buy     LUID_00003D63           Morrisons
# 13      trd_0022             Buy     LUID_00003D5Y               Tesco
# 14      trd_0015             Buy     LUID_00003D65           Rightmove
# 15      trd_0016             Buy     LUID_00003D65           Rightmove
# 16      trd_0017             Buy     LUID_00003D5Z            vodafone
# 17      trd_0018             Buy     LUID_00003D5Z            vodafone
# 18      trd_0019             Buy     LUID_00003D66  Anglo American plc
# 19      trd_0020             Buy     LUID_00003D66  Anglo American plc
# 20      trd_0014             Buy     LUID_00003D5Y               Tesco
#
#               SettlementDate  Price       Units  ResultantHolding
# 0  2020-01-04 00:00:00+00:00    5.0    120000.0          120000.0
# 1  2020-01-04 00:00:00+00:00    5.0     12000.0          132000.0
# 2  2020-01-04 00:00:00+00:00   18.0     60000.0           60000.0
# 3  2020-01-04 00:00:00+00:00   18.0     60000.0          120000.0
# 4  2020-01-04 00:00:00+00:00    2.0    150000.0          150000.0
# 5  2020-01-04 00:00:00+00:00    2.0    150000.0          300000.0
# 6  2020-01-04 00:00:00+00:00    5.0    100000.0          100000.0
# 7  2020-01-04 00:00:00+00:00    5.0    100000.0          200000.0
# 8  2020-01-04 00:00:00+00:00    6.0     20000.0           20000.0
# 9  2020-01-04 00:00:00+00:00    6.0     20000.0           40000.0
# 10 2020-01-04 00:00:00+00:00    1.0  12000000.0               NaN
# 11 2020-01-17 00:00:00+00:00    2.0    180000.0          180000.0
# 12 2020-01-17 00:00:00+00:00    2.0    180000.0          360000.0
# 13 2020-01-17 00:00:00+00:00    8.0      8000.0            8000.0
# 14 2020-01-17 00:00:00+00:00    6.0     80000.0           80000.0
# 15 2020-01-17 00:00:00+00:00    6.0     80000.0          160000.0
# 16 2020-01-17 00:00:00+00:00    1.0    450000.0          450000.0
# 17 2020-01-17 00:00:00+00:00    1.0    450000.0          900000.0
# 18 2020-01-17 00:00:00+00:00   20.0     35000.0           35000.0
# 19 2020-01-17 00:00:00+00:00   20.0     35000.0           70000.0
# 20 2020-01-18 00:00:00+00:00    9.0      4000.0           12000.0

# %%
holdings_fifth_jan.to_excel('extracts/holdings_20200105.xlsx')
